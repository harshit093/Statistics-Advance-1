# %% [markdown]
# # Theory Question

# %% [markdown]
# 1. what is a random variable in probability theory?
#   - In probability theory, a random variable is a function that assigns a numerical value to each possible outcome of a random experiment, allowing for the application of probability theory to quantify and analyze these outcomes.
#
# 2. What are the types of random variables?
#   - Random variables are classified as either discrete (taking on a finite or countably infinite number of values) or continuous (taking on any value within a given range).
#
# 3. What is the difference between discrete and continuous distributions?
#   - The key difference between discrete and continuous distributions lies in the nature of the values a random variable can take: discrete distributions have a countable, finite or infinite number of possible values, while continuous distributions can take any value within a specified range.
#
# 4. What are probability distribution functions (PDF)?
#   - Probability distribution is a function that is used to give the probability of all the possible values that a random variable can take. A discrete probability distribution can be described by a probability distribution function and a probability mass function.
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#   - While the Probability Distribution Function (PDF) describes the probability of a random variable taking on a specific value, the Cumulative Distribution Function (CDF) describes the probability of a random variable being less than or equal to a specific value.
#
# 6. What is a discrete uniform distribution?
#   - A discrete uniform distribution is a probability distribution where each outcome in a finite set of possible outcomes has the same probability of occurring. In other words, if you have a set of distinct values, each value has an equal likelihood of being selected.
#
# 7. What are the key properties of a Bernoulli distribution?
#   - The Bernoulli distribution is one of the simplest and most important probability distributions in statistics. It models a random experiment with exactly two possible outcomes, often referred to as a "success" and a "failure."
#
# 8. What is the binomial distribution, and how is it used in probability?
#   - The binomial distribution is a probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success. It is one of the most important discrete probability distributions and is used widely in statistics and probability theory.
#
# 9. What is the Poisson distribution and where is it applied?
#   - The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, under the following conditions:
#
# 1. The events occur independently of each other.
#
# 2. The average rate of occurrence is constant over time or space.
#
# 3. The events are rare in relation to the interval being observed (the probability of more than one event happening in an infinitesimally small interval is extremely small).
#
# 10. What is a continuous uniform distribution?
#   - A continuous uniform distribution is a probability distribution where all outcomes in a continuous range are equally likely to occur. This distribution is also known as a rectangular distribution because its probability density function (PDF) is flat, meaning the probability of an outcome within any subinterval of the range is proportional to the length of that subinterval.
#
# 11. What are the characteristics of a normal distribution?
#   - The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used probability distributions in statistics. It describes a continuous random variable that clusters around a central value, with the probability of values decreasing as you move further away from the center. The bell-shaped curve of the normal distribution is symmetric and is often used to model real-world phenomena.
#
# 12. What is the standard normal distribution, and why is it important?
#   - The standard normal distribution is a special case of the normal distribution where the mean μ is 0 and the standard deviation σ is 1. It is often referred to as the z-distribution, and its probability density function (PDF) has a characteristic bell-shaped curve, just like any other normal distribution, but with these specific parameters.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#   - The Central Limit Theorem (CLT) is one of the most important concepts in statistics. It states that the distribution of the sum (or average) of a large number of independent, identically distributed random variables will approach a normal distribution (Gaussian distribution) as the sample size becomes large, regardless of the original distribution of the variables.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
#   - The Central Limit Theorem (CLT) is a fundamental concept in statistics that explains how the distribution of sample means tends towards a normal distribution, regardless of the original population distribution, as the sample size increases.
#
# 15. What is the application of Z statistics in hypothesis testing?
#   - In hypothesis testing, Z-statistics (or Z-tests) are used to determine if there's a statistically significant difference between a sample mean and a population mean (or between two sample means), especially when the population standard deviation is known or the sample size is large.
#
# 16. How do you calculate a Z-score, and what does it represent?
#   - A Z-score, calculated as (x - μ) / σ, represents how many standard deviations a data point (x) is from the mean (μ) of a dataset, and is used to determine how unusual a value is compared to the rest of the dataset.
#
# 17. What are point estimates and interval estimates in statistics?
#   - In statistics, a point estimate is a single value used to estimate an unknown population parameter, while an interval estimate provides a range of plausible values for that parameter, often with a specified level of confidence.
#
# 18. What is the significance of confidence intervals in statistical analysis?
#   - Confidence intervals in statistical analysis provide a range of plausible values for a population parameter, offering a more informative and nuanced understanding of data compared to solely relying on point estimates or p-values. They help quantify uncertainty and assess the precision of estimates, aiding in making more reliable inferences and decisions.
#
# 19. What is the relationship between a Z-score and a confidence interval?
#   - A Z-score determines how many standard deviations a data point is from the mean, while a confidence interval is a range of values that likely contains the true population parameter with a certain level of confidence, and Z-scores are used to calculate the margin of error in confidence intervals.
#
# 20. How are Z-scores used to compare different distributions?
#   - Z-scores, also known as standard scores, allow for comparing data points across different distributions by standardizing values based on their distance from the mean in terms of standard deviations.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
#   - To apply the Central Limit Theorem (CLT), you need to assume that the samples are independent, identically distributed (i.i.d.) random variables, the population has a finite variance, and the sample size is sufficiently large (often considered 30 or more).
#
# 22. What is the concept of expected value in a probability distribution?
#   - In a probability distribution, the expected value (also known as the mean or mathematical expectation) is the theoretical average outcome of a random variable if the experiment is repeated many times, calculated by weighting each possible outcome by its probability.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#   - A probability distribution describes the likelihood of different outcomes for a random variable, and the expected outcome is calculated by weighting each possible value by its probability and summing these products.

# %% [markdown]
# # Practical Questions

# %%
#1. Write a Python program to generate a random variable and display its value.

import random

random_variable = random.randint(1, 100)
print("The random variable is:", random_variable)
# Out:
# The random variable is: 88

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

import numpy as np
import matplotlib.pyplot as plt

low, high = 1, 10
size = 1000

random_samples = np.random.randint(low, high + 1, size)

unique_values, counts = np.unique(random_samples, return_counts=True)

probabilities = counts / size

plt.bar(unique_values, probabilities, width=0.7, align='center', color='skyblue', edgecolor='black')
plt.title('Probability Mass Function (PMF) of a Discrete Uniform Distribution')
plt.xlabel('Values')
plt.ylabel('Probability')
plt.xticks(unique_values)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

def bernoulli_pdf(x, p):
    if x not in [0, 1]:
        raise ValueError("x must be either 0 or 1.")
    if p < 0 or p > 1:
        raise ValueError("p must be between 0 and 1 (inclusive).")

    if x == 1:
        return p
    else:
        return 1 - p

p = 0.7
x_values = [0, 1]

for x in x_values:
    print(f"P(X = {x}) = {bernoulli_pdf(x, p)}")
# Out:
# P(X = 0) = 0.30000000000000004
# P(X = 1) = 0.7

# %%
#4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

n = 10
p = 0.5
size = 10000

binomial_samples = np.random.binomial(n, p, size)

plt.hist(binomial_samples, bins=np.arange(n+2) - 0.5, density=True, edgecolor='black', alpha=0.7)
plt.title('Binomial Distribution PMF (n=10, p=0.5)')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.xticks(np.arange(0, n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#5. Create a Poisson distribution and visualize it using Python.

lambda_ = 4
size = 10000

poisson_samples = np.random.poisson(lambda_, size)

plt.hist(poisson_samples, bins=np.max(poisson_samples) - np.min(poisson_samples), density=True, edgecolor='black', alpha=0.7)
plt.title('Poisson Distribution (λ = 4)')
plt.xlabel('Number of occurrences')
plt.ylabel('Probability')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

low, high = 1, 10
size = 10000
random_samples = np.random.randint(low, high + 1, size)

unique_values, counts = np.unique(random_samples, return_counts=True)

probabilities = counts / size
cdf = np.cumsum(probabilities)

plt.step(unique_values, cdf, where='post', color='blue', linestyle='-', linewidth=2)
plt.title('Cumulative Distribution Function (CDF) of a Discrete Uniform Distribution')
plt.xlabel('Values')
plt.ylabel('CDF')
plt.xticks(np.arange(low, high + 1))
plt.grid(True)
plt.show()

# %%
#7. Generate a continuous uniform distribution using NumPy and visualize it.

low = 0
high = 10
size = 10000
uniform_samples = np.random.uniform(low, high, size)

plt.hist(uniform_samples, bins=30, density=True, edgecolor='black', alpha=0.7)

plt.title(f'Continuous Uniform Distribution\n(low={low}, high={high})')
plt.xlabel('Value')
plt.ylabel('Density')

plt.grid(True)
plt.show()

# %%
#8. Simulate data from a normal distribution and plot its histogram.

mean = 0
std_dev = 1
size = 10000
normal_samples = np.random.normal(mean, std_dev, size)
plt.hist(normal_samples, bins=30, density=True, edgecolor='black', alpha=0.7)

plt.title(f'Normal Distribution (Mean = {mean}, Std Dev = {std_dev})')
plt.xlabel('Value')
plt.ylabel('Density')

plt.grid(True)
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them.

def calculate_z_scores(data):

    mean = np.mean(data)
    std_dev = np.std(data)

    z_scores = (data - mean) / std_dev
    return z_scores

data = np.random.normal(loc=50, scale=10, size=1000)

z_scores = calculate_z_scores(data)

plt.plot(z_scores, marker='o', linestyle='none', color='b', alpha=0.5)
plt.title('Z-scores of the Dataset')
plt.xlabel('Index')
plt.ylabel('Z-score')
plt.grid(True)
plt.show()

# %%
#10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

population_size = 10000
sample_size = 30
num_samples = 1000
population_data = np.random.exponential(scale=1, size=population_size)

sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population_data, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black')

plt.title('Sampling Distribution of the Mean (Central Limit Theorem)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.grid(True)
plt.show()

print(f"Mean of sample means: {np.mean(sample_means)}")
print(f"Standard deviation of sample means: {np.std(sample_means)}")
# Out:
# Mean of sample means: 1.0008688047439407
# Standard deviation of sample means: 0.17905075750065955

# %%
#11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

population_mean = 50
population_std = 10
sample_size = 30
num_samples = 1000
population_data = np.random.normal(loc=population_mean, scale=population_std, size=10000)

sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population_data, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black')

plt.title('Sampling Distribution of the Mean (Central Limit Theorem)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.grid(True)
plt.show()

print(f"Mean of sample means: {np.mean(sample_means)}")
print(f"Standard deviation of sample means: {np.std(sample_means)}")
# Out:
# Mean of sample means: 50.00885664589763
# Standard deviation of sample means: 1.8927570306894275

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

from scipy.stats import norm

def plot_standard_normal_distribution():

    x = np.linspace(-5, 5, 1000)

    y = norm.pdf(x, loc=0, scale=1)

    plt.plot(x, y, label="Standard Normal Distribution (mean=0, std=1)", color='blue')

    plt.title("Standard Normal Distribution (mean=0, std=1)")
    plt.xlabel("X-axis")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.legend()

    plt.show()

plot_standard_normal_distribution()

# %%
#13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.
from scipy.stats import binom

def generate_binomial_data(n, p, size):
    random_variables = np.random.binomial(n, p, size)
    probabilities = binom.pmf(random_variables, n, p)
    return random_variables, probabilities

n = 10
p = 0.5
size = 1000
random_variables, probabilities = generate_binomial_data(n, p, size)

plt.hist(random_variables, bins=np.arange(n+2)-0.5, density=True, alpha=0.7, color='blue', edgecolor='black')

x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)
plt.plot(x, pmf_values, 'ro', label='PMF', markersize=10)

plt.title(f'Binomial Distribution PMF\n(n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(np.arange(0, n+1))
plt.legend()
plt.grid(True)

plt.show()
print("Some random variables and their corresponding probabilities:")
for i in range(10):
    print(f"Value: {random_variables[i]}, Probability: {probabilities[i]}")
# Out:
# Some random variables and their corresponding probabilities:
# Value: 5, Probability: 0.24609375000000003
# Value: 4, Probability: 0.2050781249999999
# Value: 5, Probability: 0.24609375000000003
# Value: 5, Probability: 0.24609375000000003
# Value: 5, Probability: 0.24609375000000003
# Value: 5, Probability: 0.24609375000000003
# Value: 3, Probability: 0.1171875
# Value: 3, Probability: 0.1171875
# Value: 5, Probability: 0.24609375000000003
# Value: 6, Probability: 0.2050781249999999

# %%
#14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

from scipy import stats

def calculate_z_score(data, x):
    mean = np.mean(data)
    std_dev = np.std(data)
    z_score = (x - mean) / std_dev
    return z_score

def plot_standard_normal_distribution():

    x = np.linspace(-5, 5, 1000)
    y = stats.norm.pdf(x, loc=0, scale=1)

    plt.plot(x, y, label="Standard Normal Distribution", color='blue')
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('X')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()

data = np.random.normal(loc=50, scale=10, size=1000)
x = 60

z_score = calculate_z_score(data, x)

cdf_value = stats.norm.cdf(z_score)

print(f"Z-score for data point {x}: {z_score}")
print(f"CDF of the standard normal distribution at Z-score {z_score}: {cdf_value}")

plot_standard_normal_distribution()

plt.axvline(x=z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.legend()

plt.show()
# Out:
# Z-score for data point 60: 0.9877909199309269
# CDF of the standard normal distribution at Z-score 0.9877909199309269: 0.8383724722915943

# %%
#15. Implement hypothesis testing using Z-statistics for a sample dataset.

from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):

    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    critical_value = norm.ppf(1 - alpha / 2)

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_statistic:.2f}")
    print(f"Critical Value: ±{critical_value:.2f}")

    if abs(z_statistic) > critical_value:
        print(f"Reject the null hypothesis (H₀). The sample mean is significantly different from {population_mean}.")
    else:
        print(f"Fail to reject the null hypothesis (H₀). The sample mean is not significantly different from {population_mean}.")

sample_data = np.array([168, 171, 175, 162, 169, 180, 177, 173, 174, 170])

population_mean = 170
population_std = 10
z_test(sample_data, population_mean, population_std, alpha=0.05)
# Out:
# Sample Mean: 171.90
# Z-statistic: 0.60
# Critical Value: ±1.96
# Fail to reject the null hypothesis (H₀). The sample mean is not significantly different from 170.

# %%
#16. Create a confidence interval for a dataset using Python and interpret the result.

data = [12, 15, 14, 10, 19, 17, 16, 15, 14, 13]

mean = np.mean(data)
std_dev = np.std(data, ddof=1)
sample_size = len(data)

confidence_level = 0.95
alpha = 1 - confidence_level

t_score = stats.t.ppf(1 - alpha / 2, df=sample_size - 1)

margin_of_error = t_score * (std_dev / np.sqrt(sample_size))

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample Mean: {mean:.2f}")
print(f"Sample Standard Deviation: {std_dev:.2f}")
print(f"Sample Size: {sample_size}")
print(f"Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 14.50
# Sample Standard Deviation: 2.55
# Sample Size: 10
# Confidence Interval: (12.68, 16.32)

# %%
#17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

mean_population = 50
std_dev_population = 10
sample_size = 100
data = np.random.normal(loc=mean_population, scale=std_dev_population, size=sample_size)

sample_mean = np.mean(data)
sample_std_dev = np.std(data, ddof=1)
sample_size = len(data)

confidence_level = 0.95
alpha = 1 - confidence_level

t_score = stats.t.ppf(1 - alpha / 2, df=sample_size - 1)

margin_of_error = t_score * (sample_std_dev / np.sqrt(sample_size))

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Standard Deviation: {sample_std_dev:.2f}")
print(f"Sample Size: {sample_size}")
print(f"Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean: 50.26
# Sample Standard Deviation: 9.18
# Sample Size: 100
# Confidence Interval: (48.44, 52.08)

# %%
#18 Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

mean = 0
std_dev = 1
x_values = np.linspace(-5, 5, 1000)
pdf_values = norm.pdf(x_values, loc=mean, scale=std_dev)

plt.plot(x_values, pdf_values, label=f'Normal Distribution (mean={mean}, std_dev={std_dev})', color='blue')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()

plt.show()

# %%
#19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

from scipy.stats import poisson

lambda_poisson = 4
k_values = np.arange(0, 15)

cdf_values = poisson.cdf(k_values, mu=lambda_poisson)

plt.plot(k_values, cdf_values, marker='o', label=f'Poisson Distribution (λ={lambda_poisson})', color='blue')
plt.title('Cumulative Distribution Function (CDF) of Poisson Distribution')
plt.xlabel('k (Number of occurrences)')
plt.ylabel('CDF')
plt.grid(True)
plt.legend()

plt.show()

for k, cdf in zip(k_values, cdf_values):
    print(f"CDF at k={k}: {cdf:.4f}")
# Out:
# CDF at k=0: 0.0183
# CDF at k=1: 0.0916
# CDF at k=2: 0.2381
# CDF at k=3: 0.4335
# CDF at k=4: 0.6288
# CDF at k=5: 0.7851
# CDF at k=6: 0.8893
# CDF at k=7: 0.9489
# CDF at k=8: 0.9786
# CDF at k=9: 0.9919
# CDF at k=10: 0.9972
# CDF at k=11: 0.9991
# CDF at k=12: 0.9997
# CDF at k=13: 0.9999
# CDF at k=14: 1.0000

# %%
#20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

a = 0
b = 10

samples = np.random.uniform(low=a, high=b, size=1000)

expected_value_theoretical = (a + b) / 2

expected_value_empirical = np.mean(samples)

print(f"Theoretical Expected Value (E[X]): {expected_value_theoretical}")
print(f"Empirical Expected Value (Mean of samples): {expected_value_empirical:.4f}")
# Out:
# Theoretical Expected Value (E[X]): 5.0
# Empirical Expected Value (Mean of samples): 4.9702

# %%
#21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

data1 = np.random.normal(loc=50, scale=5, size=1000)
data2 = np.random.normal(loc=50, scale=15, size=1000)
std_dev_data1 = np.std(data1)
std_dev_data2 = np.std(data2)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(data1, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title(f"Dataset 1\nStandard Deviation: {std_dev_data1:.2f}")
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(data2, bins=30, color='salmon', edgecolor='black', alpha=0.7)
plt.title(f"Dataset 2\nStandard Deviation: {std_dev_data2:.2f}")
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

print(f"Standard Deviation of Dataset 1: {std_dev_data1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev_data2:.2f}")
# Out:
# Standard Deviation of Dataset 1: 5.12
# Standard Deviation of Dataset 2: 14.94

# %%
#22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

mean = 50
std_dev = 10
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)

data_range = np.max(data) - np.min(data)

Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {IQR:.2f}")
# Out:
# Range of the dataset: 57.84
# Interquartile Range (IQR) of the dataset: 13.82

# %%
#23. Implement Z-score normalization on a dataset and visualize its transformation.

mean = 50
std_dev = 10
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)

mean_data = np.mean(data)
std_dev_data = np.std(data)

normalized_data = (data - mean_data) / std_dev_data

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='salmon', edgecolor='black', alpha=0.7)
plt.title('Normalized Data Distribution (Z-score)')
plt.xlabel('Normalized Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

print(f"Original Data Mean: {mean_data:.2f}, Standard Deviation: {std_dev_data:.2f}")
print(f"Normalized Data Mean: {np.mean(normalized_data):.2f}, Standard Deviation: {np.std(normalized_data):.2f}")
# Out:
# Original Data Mean: 50.20, Standard Deviation: 9.67
# Normalized Data Mean: 0.00, Standard Deviation: 1.00

# %%
#24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

from scipy.stats import skew, kurtosis

def calculate_skewness_and_kurtosis(size=1000, mean=0, std_dev=1):

    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    skewness_value = skew(data)

    kurtosis_value = kurtosis(data)

    print(f"Skewness of the dataset: {skewness_value:.4f}")
    print(f"Kurtosis of the dataset (Excess Kurtosis): {kurtosis_value:.4f}")

    return skewness_value, kurtosis_value

skewness, kurtosis_value = calculate_skewness_and_kurtosis(size=1000, mean=0, std_dev=1)
# Out:
# Skewness of the dataset: -0.1580
# Kurtosis of the dataset (Excess Kurtosis): 0.0118
